# %%
import pandas as pd
from os import listdir
import numpy as np

# %%
# Opciones de pandas
rows, cols = 100, 10
pd.set_option("display.max.columns", cols)
pd.set_option("display.max.rows", rows)
# Rutas
PATH = "../resources/"

# %%
# Generar datos de cierre de cada stock en cada trimestre
path = PATH + 'technical_data/daily/'
files = listdir(path)
for file in files:
    print("Processing stock:", file)
    data = pd.read_csv(path+file, header=0)
    data.set_index(pd.DatetimeIndex(data['Date']), inplace=True)
    data.drop(columns=['Date'], inplace=True)
    df = pd.DataFrame()
    for year in set(data.index.year):
        months = [3,6,9,12]
        for month in months:
            try:
                df = pd.concat([df, data[(data.index.month==month) & (data.index.year==year)].iloc[-1]], axis=1)
            except:
                pass
    df = df.T
    df.to_csv(PATH+'technical_data/quarterly/{}'.format(file))
# Out:
# Processing stock: AMD.csv
# Processing stock: AON.csv
# Processing stock: HES.csv
# Processing stock: IPG.csv
# Processing stock: XLNX.csv
# Processing stock: SEE.csv
# Processing stock: COF.csv
# Processing stock: VTRS.csv
# Processing stock: DG.csv
# Processing stock: FISV.csv
# Processing stock: BAX.csv
# Processing stock: EA.csv
# Processing stock: IP.csv
# Processing stock: IDXX.csv
# Processing stock: SHW.csv
# Processing stock: MSFT.csv
# Processing stock: CPRT.csv
# Processing stock: DOV.csv
# Processing stock: ETR.csv
# Processing stock: MMM.csv
# Processing stock: HPQ.csv
# Processing stock: AVB.csv
# Processing stock: TROW.csv
# Processing stock: DFS.csv
# Processing stock: KIM.csv
# Processing stock: MO.csv
# Processing stock: VAR.csv
# Processing stock: AEP.csv
# Processing stock: BA.csv
# Processing stock: TER.csv
# Processing stock: WU.csv
# Processing stock: ADM.csv
# Processing stock: AOS.csv
# Processing stock: WY.csv
# Processing stock: MAS.csv
# Processing stock: VLO.csv
# Processing stock: IRM.csv
# Processing stock: PHM.csv
# Processing stock: K.csv
# Processing stock: USB.csv
# Processing stock: PEAK.csv
# Processing stock: AEE.csv
# Processing stock: NSC.csv
# Processing stock: AZO.csv
# Processing stock: PEP.csv
# Processing stock: CI.csv
# Processing stock: ECL.csv
# Processing stock: INTC.csv
# Processing stock: VNO.csv
# Processing stock: ADBE.csv
# Processing stock: CL.csv
# Processing stock: LRCX.csv
# Processing stock: SBUX.csv
# Processing stock: XEL.csv
# Processing stock: HAS.csv
# Processing stock: SCHW.csv
# Processing stock: ZBH.csv
# Processing stock: AMAT.csv
# Processing stock: JBHT.csv
# Processing stock: NLSN.csv
# Processing stock: NUE.csv
# Processing stock: ED.csv
# Processing stock: GPS.csv
# Processing stock: MET.csv
# Processing stock: ZION.csv
# Processing stock: FRT.csv
# Processing stock: HFC.csv
# Processing stock: GM.csv
# Processing stock: MAA.csv
# Processing stock: T.csv
# Processing stock: KSU.csv
# Processing stock: ODFL.csv
# Processing stock: APD.csv
# Processing stock: HOLX.csv
# Processing stock: HUM.csv
# Processing stock: RF.csv
# Processing stock: GLW.csv
# Processing stock: DGX.csv
# Processing stock: DHI.csv
# Processing stock: LEG.csv
# Processing stock: RTX.csv
# Processing stock: JCI.csv
# Processing stock: CLX.csv
# Processing stock: CPB.csv
# Processing stock: PGR.csv
# Processing stock: LOW.csv
# Processing stock: EVRG.csv
# Processing stock: SYK.csv
# Processing stock: KO.csv
# Processing stock: ITW.csv
# Processing stock: VFC.csv
# Processing stock: CDW.csv
# Processing stock: BLL.csv
# Processing stock: WMB.csv
# Processing stock: FDX.csv
# Processing stock: MU.csv
# Processing stock: GE.csv
# Processing stock: NLOK.csv
# Processing stock: V.csv
# Processing stock: CTAS.csv
# Processing stock: TFX.csv
# Processing stock: CHRW.csv
# Processing stock: DRE.csv
# Processing stock: MSCI.csv
# Processing stock: ROK.csv
# Processing stock: QCOM.csv
# Processing stock: GL.csv
# Processing stock: WST.csv
# Processing stock: EMN.csv
# Processing stock: PPL.csv
# Processing stock: INTU.csv
# Processing stock: BIIB.csv
# Processing stock: EL.csv
# Processing stock: PRU.csv
# Processing stock: DVA.csv
# Processing stock: TRMB.csv
# Processing stock: PEG.csv
# Processing stock: DAL.csv
# Processing stock: TFC.csv
# Processing stock: BDX.csv
# Processing stock: OKE.csv
# Processing stock: STX.csv
# Processing stock: DVN.csv
# Processing stock: MS.csv
# Processing stock: ABT.csv
# Processing stock: ALK.csv
# Processing stock: CSCO.csv
# Processing stock: GIS.csv
# Processing stock: TRV.csv
# Processing stock: NI.csv
# Processing stock: KR.csv
# Processing stock: LUMN.csv
# Processing stock: TSCO.csv
# Processing stock: ORCL.csv
# Processing stock: TYL.csv
# Processing stock: LNT.csv
# Processing stock: UNP.csv
# Processing stock: JNJ.csv
# Processing stock: DPZ.csv
# Processing stock: IFF.csv
# Processing stock: CINF.csv
# Processing stock: RHI.csv
# Processing stock: SIVB.csv
# Processing stock: NEM.csv
# Processing stock: J.csv
# Processing stock: INFO.csv
# Processing stock: CAH.csv
# Processing stock: STT.csv
# Processing stock: BSX.csv
# Processing stock: WEC.csv
# Processing stock: BRK-B.csv
# Processing stock: ES.csv
# Processing stock: JKHY.csv
# Processing stock: TXT.csv
# Processing stock: PNR.csv
# Processing stock: IQV.csv
# Processing stock: PCAR.csv
# Processing stock: ESS.csv
# Processing stock: MCK.csv
# Processing stock: FCX.csv
# Processing stock: EQR.csv
# Processing stock: FIS.csv
# Processing stock: PSA.csv
# Processing stock: IVZ.csv
# Processing stock: HSY.csv
# Processing stock: NTRS.csv
# Processing stock: FITB.csv
# Processing stock: BBY.csv
# Processing stock: DHR.csv
# Processing stock: CBOE.csv
# Processing stock: BF-B.csv
# Processing stock: PLD.csv
# Processing stock: SNA.csv
# Processing stock: CSX.csv
# Processing stock: PAYX.csv
# Processing stock: UNH.csv
# Processing stock: UHS.csv
# Processing stock: L.csv
# Processing stock: CF.csv
# Processing stock: AXP.csv
# Processing stock: CHD.csv
# Processing stock: UAL.csv
# Processing stock: MA.csv
# Processing stock: BWA.csv
# Processing stock: TGT.csv
# Processing stock: AWK.csv
# Processing stock: CE.csv
# Processing stock: FRC.csv
# Processing stock: CNP.csv
# Processing stock: MDT.csv
# Processing stock: LB.csv
# Processing stock: ADSK.csv
# Processing stock: BEN.csv
# Processing stock: LLY.csv
# Processing stock: ORLY.csv
# Processing stock: AES.csv
# Processing stock: TT.csv
# Processing stock: MRK.csv
# Processing stock: DUK.csv
# Processing stock: NKE.csv
# Processing stock: AMP.csv
# Processing stock: HCA.csv
# Processing stock: HBAN.csv
# Processing stock: ALLE.csv
# Processing stock: CMCSA.csv
# Processing stock: CNC.csv
# Processing stock: ADI.csv
# Processing stock: EXR.csv
# Processing stock: RL.csv
# Processing stock: PFE.csv
# Processing stock: KEY.csv
# Processing stock: CME.csv
# Processing stock: TXN.csv
# Processing stock: ZBRA.csv
# Processing stock: ZTS.csv
# Processing stock: GS.csv
# Processing stock: LDOS.csv
# Processing stock: MMC.csv
# Processing stock: F.csv
# Processing stock: EMR.csv
# Processing stock: PH.csv
# Processing stock: HIG.csv
# Processing stock: RJF.csv
# Processing stock: CMI.csv
# Processing stock: EW.csv
# Processing stock: MTD.csv
# Processing stock: ABC.csv
# Processing stock: FMC.csv
# Processing stock: AAPL.csv
# Processing stock: PKI.csv
# Processing stock: CBRE.csv
# Processing stock: TSN.csv
# Processing stock: LUV.csv
# Processing stock: VZ.csv
# Processing stock: EXPD.csv
# Processing stock: ROL.csv
# Processing stock: CAT.csv
# Processing stock: EFX.csv
# Processing stock: O.csv
# Processing stock: PFG.csv
# Processing stock: HD.csv
# Processing stock: CFG.csv
# Processing stock: AMGN.csv
# Processing stock: PVH.csv
# Processing stock: MXIM.csv
# Processing stock: WRB.csv
# Processing stock: PKG.csv
# Processing stock: ALL.csv
# Processing stock: NWL.csv
# Processing stock: LH.csv
# Processing stock: BR.csv
# Processing stock: LIN.csv
# Processing stock: TDY.csv
# Processing stock: MSI.csv
# Processing stock: ROP.csv
# Processing stock: AIZ.csv
# Processing stock: WAT.csv
# Processing stock: SYY.csv
# Processing stock: IT.csv
# Processing stock: AAP.csv
# Processing stock: UPS.csv
# Processing stock: STE.csv
# Processing stock: AME.csv
# Processing stock: WFC.csv
# Processing stock: BXP.csv
# Processing stock: BK.csv
# Processing stock: FLIR.csv
# Processing stock: ETN.csv
# Processing stock: ADP.csv
# Processing stock: WM.csv
# Processing stock: NEE.csv
# Processing stock: FAST.csv
# Processing stock: DISCA.csv
# Processing stock: AIG.csv
# Processing stock: CMA.csv
# Processing stock: APH.csv
# Processing stock: SPGI.csv
# Processing stock: NVR.csv
# Processing stock: CVX.csv
# Processing stock: OXY.csv
# Processing stock: IBM.csv
# Processing stock: SO.csv
# Processing stock: CERN.csv
# Processing stock: LNC.csv
# Processing stock: MCD.csv
# Processing stock: KLAC.csv
# Processing stock: REG.csv
# Processing stock: SWK.csv
# Processing stock: CAG.csv
# Processing stock: GPC.csv
# Processing stock: APA.csv
# Processing stock: UDR.csv
# Processing stock: AJG.csv
# Processing stock: PNW.csv
# Processing stock: WELL.csv
# Processing stock: LEN.csv
# Processing stock: MAR.csv
# Processing stock: HRL.csv
# Processing stock: WDC.csv
# Processing stock: VRSK.csv
# Processing stock: CCL.csv
# Processing stock: HON.csv
# Processing stock: IR.csv
# Processing stock: MCO.csv
# Processing stock: DIS.csv
# Processing stock: PPG.csv
# Processing stock: WHR.csv
# Processing stock: DRI.csv
# Processing stock: CMS.csv
# Processing stock: COO.csv
# Processing stock: RE.csv
# Processing stock: ATO.csv
# Processing stock: NOV.csv
# Processing stock: VMC.csv
# Processing stock: GWW.csv
# Processing stock: DISH.csv
# Processing stock: PG.csv
# Processing stock: PBCT.csv
# Processing stock: HLT.csv
# Processing stock: HSIC.csv
# Processing stock: HAL.csv
# Processing stock: MHK.csv
# Processing stock: ABMD.csv
# Processing stock: AFL.csv
# Processing stock: STZ.csv
# Processing stock: KMB.csv
# Processing stock: DE.csv
# Processing stock: COST.csv
# Processing stock: AAL.csv
# Processing stock: PNC.csv
# Processing stock: MRO.csv
# Processing stock: SLB.csv
# Processing stock: NDAQ.csv
# Processing stock: ANSS.csv
# Processing stock: CB.csv
# Processing stock: GD.csv
# Processing stock: ROST.csv
# Processing stock: AVGO.csv
# Processing stock: DISCK.csv
# Processing stock: MTB.csv
# Processing stock: SJM.csv
# Processing stock: MKC.csv
# Processing stock: WMT.csv
# Processing stock: BIO.csv
# Processing stock: D.csv
# Processing stock: EIX.csv

# %%
# Generar dataset de acciones y atributos completo

# Importar librerías
import pandas as pd
from os import listdir

# Variables importantes
# date_include: fechas que cumplen correctamente con el patron trimestral escogido
""""date_include = ['2020-09', '2020-06', '2020-03', '2019-12', '2019-09', '2019-06',
       '2019-03', '2018-12', '2018-09', '2018-06', '2018-03', '2017-12',
       '2017-09', '2017-06', '2017-03', '2016-12', '2016-09', '2016-06',
       '2016-03', '2015-12', '2015-09', '2015-06', '2015-03', '2014-12',
       '2014-09', '2014-06', '2014-03', '2013-12', '2013-09', '2013-06',
       '2013-03', '2012-12', '2012-09', '2012-06', '2012-03', '2011-12',
       '2011-09', '2011-06', '2011-03', '2010-12', '2010-09', '2010-06',
       '2010-03', '2009-12', '2009-09', '2009-06', '2009-03', '2008-12',
       '2008-09', '2008-06', '2008-03', '2007-12', '2007-09', '2007-06',
       '2007-03', '2006-12', '2006-09', '2006-06', '2006-03', '2005-12',
       '2005-09', '2005-06', '2005-03', '2004-12', '2004-09', '2004-06',
       '2004-03', '2003-12', '2003-09', '2003-06', '2003-03', '2002-12',
       '2002-09', '2002-06', '2002-03', '2001-12', '2001-09', '2001-06',
       '2001-03', '2000-12', '2000-09', '2000-06', '2000-03', '1999-12',
       '1999-09', '1999-06', '1999-03', '1998-12', '1998-09', '1998-06']"""
# stock_drops: stocks que tienen datos faltantes en el atributo 'Revenue'
# stock_drops = ['HFC', 'ROP', 'AMAT', 'FRC', 'PKG', 'DLTR', 'SIVB', 'BBY', 'EQR', 'CSCO', 'CPRT', 'BF.B', 'CTAS', 'HPQ', 'AKAM', 'STZ', 'TTWO', 'FFIV', 'GIS', 'KR', 'COST', 'STT', 'DRI', 'ISRG', 'ADM', 'LEN', 'WBA', 'LOW', 'ADI', 'RF', 'ADBE', 'MET', 'SCHW', 'HRL', 'DE', 'ROST', 'GPS', 'SJM', 'NKE', 'WMT', 'AZO', 'TIF', 'NTAP', 'CAG', 'HBAN', 'SNPS', 'LHX', 'MKC', 'EQIX', 'VTRS', 'ZION', 'BKNG', 'VTR', 'ADSK', 'CDW', 'KMX', 'MS', 'ORCL', 'VAR', 'LB', 'TGT', 'MOS', 'TJX', 'COO', 'HD', 'JNPR', 'INTU', 'UPS', 'GS', 'PVH', 'PBCT', 'MDT', 'OKE', 'TPR', 'EW', 'SBAC', 'DG', 'NVDA', 'NRG', 'CCL', 'DAL', 'CHTR', 'PAYX', 'BK', 'ILMN', 'A', 'BLK', 'ALXN', 'FDX', 'MU', 'CPB', 'KEY']
# stock_drops += ['LUMN','VIAC','WRK','HCA','UAL','AAL','TDY','EBAY','CCI','RSG','SRE','CTSH']
stock_list = []

# Unir income, balance y cash
path = PATH + 'fundamental_data/csvs/'
path_tech = PATH + 'technical_data/quarterly/'
stocks = listdir(path)
#stocks = list(set(stocks) - set(stock_drops))
#stocks.sort()
all_data = pd.DataFrame()

for stock in stocks:
    files = listdir(path+stock+'/')
    df = pd.DataFrame()
    doubl_netinc = True
    for file in files:
        data = pd.read_csv(path+stock+'/'+file, header=0, index_col=0)
        data.set_index(pd.DatetimeIndex(list(data.index)), inplace=True)
        data.index = data.index.strftime('%Y-%m')
        data = data.loc[:, ~data.columns.str.contains('^Unnamed')]
        data.drop(['AsOriginallyReported', 'Restated'], axis=1, inplace=True)
        if doubl_netinc:    # Se borrar NetIncome que se encuentra repetido
            try:
                data.drop(columns=['NetIncome'], inplace=True) 
                doubl_netinc = False
            except:
                pass
        df = pd.concat([df, data], axis=1)

    # Poner todas las unidades en Billones Americanos
    d = {'M': '*0.001', 'B': '', 'T': '*1000'}
    df = df.replace(d, regex=True)
    df = df.applymap(pd.eval, na_action='ignore')

    # Crear nuevos atributos necesarios para realizar cálculos en ratios y demás indicadores
    eps_ttm, netcashop_ttm, netcapex_ttm, revenue_ttm, netincome_ttm = [None for _ in range(len(df.index))], [None for _ in range(len(df.index))], [None for _ in range(len(df.index))], [None for _ in range(len(df.index))], [None for _ in range(len(df.index))]
    try:
        for i in range(len(df.index)-4, -1, -1):
                eps_ttm[i] = df['EPSDiluted'][i] + df['EPSDiluted'][i+1] + df['EPSDiluted'][i+2] + df['EPSDiluted'][i+3]
                netcashop_ttm[i] = df['CashfromOperations'][i] + df['CashfromOperations'][i+1] + df['CashfromOperations'][i+2] + df['CashfromOperations'][i+3]
                netcapex_ttm[i] = df['NetChangeinCapitalExpenditures'][i] + df['NetChangeinCapitalExpenditures'][i+1] + df['NetChangeinCapitalExpenditures'][i+2] + df['NetChangeinCapitalExpenditures'][i+3]
                revenue_ttm[i] = df['Revenue'][i] + df['Revenue'][i+1] + df['Revenue'][i+2] + df['Revenue'][i+3]
                netincome_ttm[i] = df['NetIncome'][i] + df['NetIncome'][i+1] + df['NetIncome'][i+2] + df['NetIncome'][i+3]
        df['EPSDiluted(TTM)'] = eps_ttm
        df['CashfromOperations(TTM)'] = netcashop_ttm
        df['NetChangeinCapitalExpenditures(TTM)'] = netcapex_ttm
        df['Revenue(TTM)'] = revenue_ttm
        df['NetIncome(TTM)'] = netincome_ttm
    except:
        continue
    
    # Añadir la colomnua de precios (Close adj) al dataset
    data = pd.read_csv(path_tech+stock+'.csv',header=0, index_col=0)
    data.set_index(pd.DatetimeIndex(list(data.index)), inplace=True)
    data.index = data.index.strftime('%Y-%m')
    df = pd.concat([df,data['Close']], axis=1).sort_index(axis=0, ascending=False)
    df.rename(columns={'Close':'PricePerShare'}, inplace=True)

    # Calcular y agregar ratios e indicadores
    peg, roe = [None for _ in range(len(df.index))], [None for _ in range(len(df.index))]
    df['P/E'] = df.apply(lambda col: col['PricePerShare'] / col['EPSDiluted(TTM)'], axis=1)
    for i in range(len(df.index)-6, -1, -1):
        peg[i] = df['P/E'][i] / ((df['EPSDiluted(TTM)'][i] / df['EPSDiluted(TTM)'][i+5] - 1) * 100)
        bv_act = (df['TotalAssets'][i] - df['TotalLiabilities'][i])
        bv_past = (df['TotalAssets'][i+5] - df['TotalLiabilities'][i+5])
        try:
            roe[i] = df['NetIncome(TTM)'][i] / ((bv_act + bv_past) / 2) * 100
        except:
            roe[i] = None
    df['PEG'] = peg
    try:
        df['FCF'] = df.apply(lambda col: col['CashfromOperations(TTM)'] + col['NetChangeinCapitalExpenditures(TTM)'], axis=1)
        df['P/FCF'] = df.apply(lambda col: col['PricePerShare'] / (col['FCF'] / col['AverageBasicSharesOutstanding']), axis=1)
        df['P/S'] = df.apply(lambda col: (col['PricePerShare'] * col['AverageBasicSharesOutstanding']) / col['Revenue(TTM)'], axis=1)
        df['P/B'] = df.apply(lambda col: col['PricePerShare'] / ((col['TotalAssets'] - col['TotalLiabilities']) / col['AverageBasicSharesOutstanding']), axis=1)
    except:
        continue
    df['ROE'] = roe

    # Eliminar todos los atributos que no se encuentran en la lista de incluídos
    #included = ['Revenue','GrossProfit','SG&AExpense','ResearchandDevelopmentExpense','NetOperatingInterestIncome','TotalOperatingExpenses','OperatingIncome','NetNon-OperatingInterestIncomeExpense','OtherIncomeandExpenses','NetInterestIncome','IncomefromContinuingOperations','NetIncome','EBIT','EPSBasic','EPSDiluted','AverageBasicSharesOutstanding','DividendPerShare','Cash','CashandEquivalents','ShortTermInvestments','TotalReceivables','Inventories','TotalCurrentAssets','LandandImprovements','NetPP&E','TotalLongTermAssets','TotalAssets','PayablesandAccruedExpenses','CurrentDebt&CapitalLeaseObligation','CurrentDeferredRevenue','CurrentDeferredLiabilities','TotalCurrentLiabilities','TotalLongTermLiabilities','TotalLiabilities','TotalCapitalStock','RetainedEarnings','PreferredStock','ShareholdersEquity','NetIncome','TotalDepreciation,Amortization,Depletion','DeferredTaxes','StockBasedCompensation','OtherNoncashItems','CashfromOperations','SaleofPPE','NetChangeinPP&E','NetDivestitures(Acquisitions)','TotalNetChangeinInvestments','CashfromInvesting','NetChangeinLongTermDebt','NetChangeinShortTermDebt','NetDebtIssuance','TotalDividendsPaid','CashfromFinancing','BeginningCash','ChangeinCash','EndingCash','IssuanceofDebt','DebtRepayment','RepurchaseofCapitalStock','EPSDiluted(TTM)','CashfromOperations(TTM)','NetChangeinCapitalExpenditures(TTM)','Revenue(TTM)','P/E','PEG','FCF','P/FCF','P/S','P/B','ROE','PricePerShare']
    #drops = list( set(df.columns) - set(included))
    #df.drop(drops, axis=1, inplace=True)
    
    df.columns = pd.MultiIndex.from_product([df.columns, [stock]], names=['Attributes', 'Symbol'])
    all_data = pd.concat([all_data, df], axis=1).sort_index(axis=1)
    print('Procesando stock:',stock)
    stock_list.append(stock)
#date_drops = list( set(all_data.index) - set(date_include) )
#all_data.drop(date_drops, axis=0, errors='ignore', inplace=True)
all_data.to_csv(PATH+'fundamental_data/backup/complete_dataset.csv')
print(stock_list)
print(len(stock_list))
# Out:
# <ipython-input-7-57da480f9443>:86: RuntimeWarning: divide by zero encountered in double_scalars
#   df['P/E'] = df.apply(lambda col: col['PricePerShare'] / col['EPSDiluted(TTM)'], axis=1)
# <ipython-input-7-57da480f9443>:88: RuntimeWarning: divide by zero encountered in double_scalars
#   peg[i] = df['P/E'][i] / ((df['EPSDiluted(TTM)'][i] / df['EPSDiluted(TTM)'][i+5] - 1) * 100)
# Procesando stock: OXY
# Procesando stock: BRK.B
# Procesando stock: WY
# Procesando stock: NKE
# Procesando stock: SIVB
# Procesando stock: J
# Procesando stock: IDXX
# Procesando stock: ADSK
# Procesando stock: MAS
# Procesando stock: EMR
# Procesando stock: FISV
# Procesando stock: ESS
# Procesando stock: HD
# Procesando stock: LH
# Procesando stock: TSN
# Procesando stock: AME
# Procesando stock: SCHW
# Procesando stock: SLB
# Procesando stock: LOW
# Procesando stock: CME
# Procesando stock: CAG
# Procesando stock: BIO
# Procesando stock: EA
# Procesando stock: AZO
# Procesando stock: AIG
# Procesando stock: IRM
# Procesando stock: KLAC
# Procesando stock: WAT
# Procesando stock: PLD
# Procesando stock: PEAK
# Procesando stock: GE
# Procesando stock: BK
# Procesando stock: GL
# Procesando stock: DRE
# Procesando stock: NTRS
# Procesando stock: SHW
# Procesando stock: CMA
# Procesando stock: RTX
# Procesando stock: DISCA
# Procesando stock: PEG
# Procesando stock: EIX
# Procesando stock: NOV
# Procesando stock: NLOK
# Procesando stock: DAL
# Procesando stock: VZ
# Procesando stock: GIS
# Procesando stock: PH
# Procesando stock: APD
# Procesando stock: MRK
# Procesando stock: ZTS
# Procesando stock: TDY
# Procesando stock: AIZ
# Procesando stock: MS
# Procesando stock: BR
# Procesando stock: COF
# Procesando stock: ZION
# Procesando stock: AWK
# Procesando stock: ROP
# Procesando stock: UDR
# Procesando stock: APH
# Procesando stock: V
# Procesando stock: HUM
# Procesando stock: TER
# Procesando stock: MSCI
# Procesando stock: MMC
# Procesando stock: WMT
# Procesando stock: MO
# Procesando stock: LUV
# Procesando stock: QCOM
# Procesando stock: ORLY
# Procesando stock: TXT
# Procesando stock: ABMD
# Procesando stock: MTB
# Procesando stock: ALK
# Procesando stock: HFC
# Procesando stock: ECL
# Procesando stock: KEY
# <ipython-input-7-57da480f9443>:98: RuntimeWarning: divide by zero encountered in double_scalars
#   df['P/FCF'] = df.apply(lambda col: col['PricePerShare'] / (col['FCF'] / col['AverageBasicSharesOutstanding']), axis=1)
# Procesando stock: FAST
# Procesando stock: ALL
# Procesando stock: L
# Procesando stock: USB
# Procesando stock: AEP
# Procesando stock: WST
# Procesando stock: AEE
# Procesando stock: DHI
# Procesando stock: SBUX
# Procesando stock: HSIC
# Procesando stock: TFC
# Procesando stock: SJM
# Procesando stock: KO
# Procesando stock: AVB
# Procesando stock: CF
# Procesando stock: AON
# Procesando stock: VAR
# <ipython-input-7-57da480f9443>:100: RuntimeWarning: divide by zero encountered in double_scalars
#   df['P/B'] = df.apply(lambda col: col['PricePerShare'] / ((col['TotalAssets'] - col['TotalLiabilities']) / col['AverageBasicSharesOutstanding']), axis=1)
# Procesando stock: MCO
# Procesando stock: PFG
# Procesando stock: CAT
# Procesando stock: SEE
# Procesando stock: CHRW
# Procesando stock: ADM
# Procesando stock: LEG
# Procesando stock: PCAR
# Procesando stock: DHR
# Procesando stock: EXPD
# Procesando stock: IT
# Procesando stock: CDW
# Procesando stock: KSU
# Procesando stock: XEL
# Procesando stock: VNO
# Procesando stock: LUMN
# Procesando stock: PNC
# Procesando stock: XLNX
# Procesando stock: PKI
# Procesando stock: DPZ
# Procesando stock: MSFT
# Procesando stock: DE
# Procesando stock: CE
# Procesando stock: D
# Procesando stock: BSX
# Procesando stock: DGX
# Procesando stock: ES
# Procesando stock: CPB
# Procesando stock: CCL
# Procesando stock: COST
# Procesando stock: NUE
# Procesando stock: EXR
# Procesando stock: CMCSA
# Procesando stock: ORCL
# Procesando stock: LDOS
# Procesando stock: CNP
# Procesando stock: SO
# Procesando stock: NWL
# Procesando stock: O
# Procesando stock: DVA
# Procesando stock: SPGI
# Procesando stock: ABT
# Procesando stock: HIG
# Procesando stock: IBM
# Procesando stock: MSI
# Procesando stock: AFL
# Procesando stock: AES
# Procesando stock: GLW
# Procesando stock: TFX
# Procesando stock: HLT
# Procesando stock: ROL
# Procesando stock: GS
# Procesando stock: MET
# Procesando stock: MTD
# Procesando stock: WHR
# Procesando stock: KR
# Procesando stock: BF.B
# Procesando stock: WM
# Procesando stock: CMI
# Procesando stock: MCK
# Procesando stock: MMM
# Procesando stock: ADI
# Procesando stock: GWW
# Procesando stock: HCA
# Procesando stock: LEN
# Procesando stock: IPG
# Procesando stock: BXP
# Procesando stock: NVR
# Procesando stock: CNC
# Procesando stock: MRO
# Procesando stock: DOV
# Procesando stock: MAR
# Procesando stock: PNW
# Procesando stock: NEM
# Procesando stock: CTAS
# Procesando stock: WMB
# Procesando stock: CERN
# Procesando stock: PAYX
# Procesando stock: AOS
# Procesando stock: ABC
# Procesando stock: CBOE
# Procesando stock: HES
# Procesando stock: ANSS
# Procesando stock: T
# Procesando stock: DIS
# Procesando stock: EFX
# Procesando stock: PBCT
# Procesando stock: FMC
# Procesando stock: GD
# Procesando stock: PG
# Procesando stock: ZBH
# Procesando stock: APA
# Procesando stock: NSC
# Procesando stock: UNP
# Procesando stock: CFG
# Procesando stock: AXP
# Procesando stock: EVRG
# Procesando stock: BWA
# Procesando stock: ED
# Procesando stock: VFC
# Procesando stock: LRCX
# Procesando stock: WEC
# Procesando stock: SWK
# Procesando stock: RL
# Procesando stock: PPG
# Procesando stock: FCX
# Procesando stock: MAA
# Procesando stock: MCD
# Procesando stock: IP
# Procesando stock: K
# Procesando stock: PEP
# Procesando stock: REG
# Procesando stock: TSCO
# Procesando stock: PVH
# Procesando stock: DFS
# Procesando stock: ETR
# Procesando stock: F
# Procesando stock: JBHT
# Procesando stock: GPS
# Procesando stock: DVN
# Procesando stock: HPQ
# Procesando stock: WFC
# Procesando stock: UHS
# Procesando stock: BDX
# Procesando stock: ETN
# Procesando stock: IFF
# Procesando stock: AAP
# Procesando stock: TXN
# Procesando stock: ALLE
# Procesando stock: PNR
# Procesando stock: CMS
# Procesando stock: WRB
# Procesando stock: CSCO
# Procesando stock: MXIM
# Procesando stock: ROK
# Procesando stock: VRSK
# Procesando stock: PPL
# Procesando stock: EQR
# Procesando stock: GPC
# Procesando stock: SYK
# Procesando stock: INTC
# Procesando stock: SYY
# Procesando stock: STX
# Procesando stock: PKG
# Procesando stock: DISCK
# Procesando stock: RJF
# Procesando stock: NLSN
# Procesando stock: SNA
# Procesando stock: FDX
# Procesando stock: AVGO
# Procesando stock: MU
# Procesando stock: NDAQ
# Procesando stock: TT
# Procesando stock: EMN
# Procesando stock: CHD
# Procesando stock: LB
# Procesando stock: BA
# Procesando stock: MKC
# Procesando stock: VMC
# Procesando stock: COO
# Procesando stock: VLO
# Procesando stock: MA
# Procesando stock: VTRS
# Procesando stock: RF
# Procesando stock: RHI
# Procesando stock: JKHY
# Procesando stock: LLY
# Procesando stock: AMGN
# Procesando stock: BAX
# Procesando stock: ITW
# Procesando stock: LNT
# Procesando stock: OKE
# Procesando stock: UNH
# Procesando stock: CSX
# Procesando stock: INFO
# Procesando stock: HAL
# Procesando stock: CL
# Procesando stock: AAL
# Procesando stock: IQV
# Procesando stock: KMB
# Procesando stock: PGR
# Procesando stock: HON
# Procesando stock: FRT
# Procesando stock: ROST
# Procesando stock: LNC
# Procesando stock: LIN
# Procesando stock: KIM
# Procesando stock: AMAT
# Procesando stock: ADBE
# Procesando stock: CINF
# Procesando stock: CPRT
# Procesando stock: HAS
# Procesando stock: ZBRA
# Procesando stock: PHM
# Procesando stock: CAH
# Procesando stock: PSA
# Procesando stock: UPS
# Procesando stock: NEE
# Procesando stock: HRL
# Procesando stock: DG
# Procesando stock: TROW
# Procesando stock: BBY
# Procesando stock: ODFL
# Procesando stock: DUK
# Procesando stock: HBAN
# Procesando stock: AMD
# Procesando stock: GM
# Procesando stock: TRV
# Procesando stock: DISH
# Procesando stock: STT
# Procesando stock: NI
# Procesando stock: IVZ
# Procesando stock: TGT
# Procesando stock: EL
# Procesando stock: FLIR
# Procesando stock: UAL
# Procesando stock: FRC
# Procesando stock: CBRE
# Procesando stock: CVX
# Procesando stock: HOLX
# Procesando stock: CB
# Procesando stock: BEN
# Procesando stock: AJG
# Procesando stock: WU
# Procesando stock: AMP
# Procesando stock: PRU
# Procesando stock: HSY
# Procesando stock: EW
# Procesando stock: FITB
# Procesando stock: AAPL
# Procesando stock: FIS
# Procesando stock: PFE
# Procesando stock: STZ
# Procesando stock: DRI
# Procesando stock: WDC
# Procesando stock: BIIB
# Procesando stock: ADP
# Procesando stock: BLL
# Procesando stock: CLX
# Procesando stock: TRMB
# Procesando stock: WELL
# Procesando stock: JNJ
# Procesando stock: JCI
# Procesando stock: ATO
# Procesando stock: MHK
# Procesando stock: CI
# Procesando stock: STE
# Procesando stock: TYL
# Procesando stock: IR
# Procesando stock: INTU
# Procesando stock: MDT
# ['OXY', 'BRK.B', 'WY', 'NKE', 'SIVB', 'J', 'IDXX', 'ADSK', 'MAS', 'EMR', 'FISV', 'ESS', 'HD', 'LH', 'TSN', 'AME', 'SCHW', 'SLB', 'LOW', 'CME', 'CAG', 'BIO', 'EA', 'AZO', 'AIG', 'IRM', 'KLAC', 'WAT', 'PLD', 'PEAK', 'GE', 'BK', 'GL', 'DRE', 'NTRS', 'SHW', 'CMA', 'RTX', 'DISCA', 'PEG', 'EIX', 'NOV', 'NLOK', 'DAL', 'VZ', 'GIS', 'PH', 'APD', 'MRK', 'ZTS', 'TDY', 'AIZ', 'MS', 'BR', 'COF', 'ZION', 'AWK', 'ROP', 'UDR', 'APH', 'V', 'HUM', 'TER', 'MSCI', 'MMC', 'WMT', 'MO', 'LUV', 'QCOM', 'ORLY', 'TXT', 'ABMD', 'MTB', 'ALK', 'HFC', 'ECL', 'KEY', 'FAST', 'ALL', 'L', 'USB', 'AEP', 'WST', 'AEE', 'DHI', 'SBUX', 'HSIC', 'TFC', 'SJM', 'KO', 'AVB', 'CF', 'AON', 'VAR', 'MCO', 'PFG', 'CAT', 'SEE', 'CHRW', 'ADM', 'LEG', 'PCAR', 'DHR', 'EXPD', 'IT', 'CDW', 'KSU', 'XEL', 'VNO', 'LUMN', 'PNC', 'XLNX', 'PKI', 'DPZ', 'MSFT', 'DE', 'CE', 'D', 'BSX', 'DGX', 'ES', 'CPB', 'CCL', 'COST', 'NUE', 'EXR', 'CMCSA', 'ORCL', 'LDOS', 'CNP', 'SO', 'NWL', 'O', 'DVA', 'SPGI', 'ABT', 'HIG', 'IBM', 'MSI', 'AFL', 'AES', 'GLW', 'TFX', 'HLT', 'ROL', 'GS', 'MET', 'MTD', 'WHR', 'KR', 'BF.B', 'WM', 'CMI', 'MCK', 'MMM', 'ADI', 'GWW', 'HCA', 'LEN', 'IPG', 'BXP', 'NVR', 'CNC', 'MRO', 'DOV', 'MAR', 'PNW', 'NEM', 'CTAS', 'WMB', 'CERN', 'PAYX', 'AOS', 'ABC', 'CBOE', 'HES', 'ANSS', 'T', 'DIS', 'EFX', 'PBCT', 'FMC', 'GD', 'PG', 'ZBH', 'APA', 'NSC', 'UNP', 'CFG', 'AXP', 'EVRG', 'BWA', 'ED', 'VFC', 'LRCX', 'WEC', 'SWK', 'RL', 'PPG', 'FCX', 'MAA', 'MCD', 'IP', 'K', 'PEP', 'REG', 'TSCO', 'PVH', 'DFS', 'ETR', 'F', 'JBHT', 'GPS', 'DVN', 'HPQ', 'WFC', 'UHS', 'BDX', 'ETN', 'IFF', 'AAP', 'TXN', 'ALLE', 'PNR', 'CMS', 'WRB', 'CSCO', 'MXIM', 'ROK', 'VRSK', 'PPL', 'EQR', 'GPC', 'SYK', 'INTC', 'SYY', 'STX', 'PKG', 'DISCK', 'RJF', 'NLSN', 'SNA', 'FDX', 'AVGO', 'MU', 'NDAQ', 'TT', 'EMN', 'CHD', 'LB', 'BA', 'MKC', 'VMC', 'COO', 'VLO', 'MA', 'VTRS', 'RF', 'RHI', 'JKHY', 'LLY', 'AMGN', 'BAX', 'ITW', 'LNT', 'OKE', 'UNH', 'CSX', 'INFO', 'HAL', 'CL', 'AAL', 'IQV', 'KMB', 'PGR', 'HON', 'FRT', 'ROST', 'LNC', 'LIN', 'KIM', 'AMAT', 'ADBE', 'CINF', 'CPRT', 'HAS', 'ZBRA', 'PHM', 'CAH', 'PSA', 'UPS', 'NEE', 'HRL', 'DG', 'TROW', 'BBY', 'ODFL', 'DUK', 'HBAN', 'AMD', 'GM', 'TRV', 'DISH', 'STT', 'NI', 'IVZ', 'TGT', 'EL', 'FLIR', 'UAL', 'FRC', 'CBRE', 'CVX', 'HOLX', 'CB', 'BEN', 'AJG', 'WU', 'AMP', 'PRU', 'HSY', 'EW', 'FITB', 'AAPL', 'FIS', 'PFE', 'STZ', 'DRI', 'WDC', 'BIIB', 'ADP', 'BLL', 'CLX', 'TRMB', 'WELL', 'JNJ', 'JCI', 'ATO', 'MHK', 'CI', 'STE', 'TYL', 'IR', 'INTU', 'MDT']
# 345
