cv = ShuffleSplit(n_splits=10, test_size=0.2)
svr = GridSearchCV(SVR(), n_jobs=-1, error_score=1, cv=cv,
                   param_grid={"kernel": ['linear', 'poly', 'rbf', 'sigmoid'],
                               "C": [1, 3, 5, 7],
                               "gamma": [0.00009, 0.00008, 0.00007, 0.00006, 0.0001],
                                "epsilon": [0.0001, 0.0003, 0.0005, 0.0008, 0.01]
                              },
                   scoring="neg_root_mean_squared_error"
)
data = pd.read_csv(PATH+'Windowed_IBM_Manual_dataset.csv', header=0, index_col=0, low_memory=False)
data.sort_index(ascending=True, inplace=True)
print(param_tuner(data,svr,scaling=False))
# Out:
# {'C': 7, 'epsilon': 0.01, 'gamma': 9e-05, 'kernel': 'linear'}

# %%
from lib.fundamental_lib import evaluate_estimator
from sklearn.model_selection import ShuffleSplit
#Params={'C': 7, 'epsilon': 0.0003, 'gamma': 9e-05, 'kernel': 'linear'}
#Params={'C': 7, 'epsilon': 0.01, 'gamma': 9e-05, 'kernel': 'linear'}
Params={'C': 7, 'epsilon': 0.01, 'gamma': 9e-05, 'kernel': 'linear'}
svr = SVR(kernel=Params['kernel'], C=Params['C'], gamma=Params['gamma'], epsilon=Params['epsilon'])
cv = ShuffleSplit(n_splits=10, test_size=0.2)
evaluate_estimator('Windowed_{}_Manual_dataset.csv', PATH, svr, cv=cv, scaling=False)
# Out:
# NSC
# neg_mean_absolute_percentage_error
# 	mean: 0.17024287068131583	 std:0.03143184610179545
#
#
# NSC
# neg_root_mean_squared_error
# 	mean: 9.624705273038776	 std:3.480502642246731
#
#
# GL
# neg_mean_absolute_percentage_error
# 	mean: 0.1860223555162172	 std:0.029179766818691284
#
#
# GL
# neg_root_mean_squared_error
# 	mean: 4.890165887091799	 std:1.1418854294307081
#
#
# PEP
# neg_mean_absolute_percentage_error
# 	mean: 0.10887375372495559	 std:0.017637191528443702
#
#
# PEP
# neg_root_mean_squared_error
# 	mean: 4.217040096600165	 std:1.1299318353738637
#
#
# BDX
# neg_mean_absolute_percentage_error
# 	mean: 0.1386756177919383	 std:0.0197124154557115
#
#
# BDX
# neg_root_mean_squared_error
# 	mean: 9.725332839241522	 std:2.022409103590666
#
#
# IBM
# neg_mean_absolute_percentage_error
# 	mean: 0.21107163506824814	 std:0.06329909053008902
#
#
# IBM
# neg_root_mean_squared_error
# 	mean: 10.829629439550548	 std:1.503026854122762
#
#
# MEAN MAPE: 0.162977246556535
# 	 STD: 0.032252062086946184
# MEAN RMSE: 7.857374707104563
# 	 STD: 1.855551172952946

# %% [markdown]
# ## 2.2 Scaled y dataset evaluation

# %%
from lib.fundamental_lib import param_tuner
from sklearn.model_selection import ShuffleSplit
stocks = ['NSC', 'GL', 'PEP', 'BDX', 'IBM']
cv = ShuffleSplit(n_splits=10, test_size=0.2)
svr = GridSearchCV(SVR(), n_jobs=-1, error_score=1, cv=cv,
                   param_grid={"kernel": ['linear', 'poly', 'rbf', 'sigmoid'],
                               "C": [1, 3, 5, 7],
                               "gamma": [0.00009, 0.00008, 0.00007, 0.00006, 0.0001],
                                "epsilon": [0.0001, 0.0003, 0.0005, 0.0008, 0.01]
                              },
                   scoring="neg_root_mean_squared_error"
)
data = pd.read_csv(PATH+'Windowed_IBM_Manual_dataset.csv', header=0, index_col=0, low_memory=False)
data.sort_index(ascending=True, inplace=True)
print(param_tuner(data,svr,scaling=True))
# Out:
# {'C': 1, 'epsilon': 0.01, 'gamma': 9e-05, 'kernel': 'linear'}

# %%
from lib.fundamental_lib import evaluate_estimator
from sklearn.model_selection import ShuffleSplit
#Params={'C': 7, 'epsilon': 0.0003, 'gamma': 9e-05, 'kernel': 'linear'}
#Params={'C': 7, 'epsilon': 0.01, 'gamma': 9e-05, 'kernel': 'linear'}
Params={'C': 1, 'epsilon': 0.01, 'gamma': 9e-05, 'kernel': 'linear'}
svr = SVR(kernel=Params['kernel'], C=Params['C'], gamma=Params['gamma'], epsilon=Params['epsilon'])
cv = ShuffleSplit(n_splits=10, test_size=0.2)
evaluate_estimator('Windowed_{}_Manual_dataset.csv', PATH, svr, cv=cv, scaling=True)
# Out:
# NSC
# neg_mean_absolute_percentage_error
# 	mean: 0.4088226471754276	 std:0.333145620936082
#
#
# NSC
# neg_root_mean_squared_error
# 	mean: 0.2537673868529942	 std:0.06407743957996379
#
#
# GL
# neg_mean_absolute_percentage_error
# 	mean: 3.98264527865405	 std:10.883344572032199
#
#
# GL
# neg_root_mean_squared_error
# 	mean: 0.171607403564924	 std:0.06107128064072382
#
#
# PEP
# neg_mean_absolute_percentage_error
# 	mean: 0.31622862387806155	 std:0.07599359740791352
#
#
# PEP
# neg_root_mean_squared_error
# 	mean: 0.14452772135939929	 std:0.03870536681988938
#
#
# BDX
# neg_mean_absolute_percentage_error
# 	mean: 1.6289828845423149	 std:1.7605501692641692
#
#
# BDX
# neg_root_mean_squared_error
# 	mean: 0.1398439623619092	 std:0.018883695036948187
#
#
# IBM
# neg_mean_absolute_percentage_error
# 	mean: 0.5680902891471307	 std:0.45615676731324223
#
#
# IBM
# neg_root_mean_squared_error
# 	mean: 0.2197935852997494	 std:0.03224573213675745
#
#
# MEAN MAPE: 1.380953944679397
# 	 STD: 2.701838145390721
# MEAN RMSE: 0.18590801188779524
# 	 STD: 0.042996702842856525

# %% [markdown]
# ## 3.0 Model testing settings

# %%
from lib.fundamental_lib import make_dict
datas = make_dict('Windowed_{}_Manual_dataset.csv', PATH)

# %% [markdown]
# ## 3.1 Random split - No scaled prediction variable

# %%
# Sin generar un train estructurado
from lib.fundamental_lib import model_results_revised
#Best Params
#Params={'C': 7, 'epsilon': 0.0001, 'gamma': 9e-05, 'kernel': 'linear', 'rs': [0, 2, 3, 4, 8]} #2
#Params={'C': 7, 'epsilon': 0.01, 'gamma': 9e-05, 'kernel': 'linear', 'rs': [0, 2, 3, 5, 8, 9]} #1
#Params={'C': 7, 'epsilon': 0.0003, 'gamma': 9e-05, 'kernel': 'linear'}
#Params={'C': 7, 'epsilon': 0.01, 'gamma': 9e-05, 'kernel': 'linear'}
Params={'C': 7, 'epsilon': 0.01, 'gamma': 9e-05, 'kernel': 'linear'}
svr = SVR(kernel=Params['kernel'], C=Params['C'], gamma=Params['gamma'], epsilon=Params['epsilon'])
for stock in ['NSC', 'GL', 'PEP', 'BDX', 'IBM']:
    model_results_revised(datas[stock], svr, label=stock, scaling=False, start='1986-03')
# Out:
# NSC MODEL RESULTS
#  RMSE
#  	Test: 8.574428956352016
#  MAPE
#  	Test: 0.17049118999056895
#  MAE
#  	Test: 5.328817399281227
#  R2 Score Adj
#  	Test: 0.9576718312986132
# GL MODEL RESULTS
#  RMSE
#  	Test: 4.529008971838418
#  MAPE
#  	Test: 0.13370010557512993
#  MAE
#  	Test: 2.7031766691665924
#  R2 Score Adj
#  	Test: 0.9559495380221692
# PEP MODEL RESULTS
#  RMSE
#  	Test: 5.290273203180613
#  MAPE
#  	Test: 0.11035423814129865
#  MAE
#  	Test: 2.853635019546558
#  R2 Score Adj
#  	Test: 0.9684155058714606
# BDX MODEL RESULTS
#  RMSE
#  	Test: 6.687411312840727
#  MAPE
#  	Test: 0.11051261355703888
#  MAE
#  	Test: 4.1508410694287345
#  R2 Score Adj
#  	Test: 0.9875033297348796
# IBM MODEL RESULTS
#  RMSE
#  	Test: 9.891971539199568
#  MAPE
#  	Test: 0.1818477206639421
#  MAE
#  	Test: 6.859877236076775
#  R2 Score Adj
#  	Test: 0.9407948442664473

# %% [markdown]
# ## 3.2 Random split - Scaled prediction variable

# %%
# Sin generar un train estructurado
from lib.fundamental_lib import model_results_revised
#Best Params
#Params={'C': 7, 'epsilon': 0.0001, 'gamma': 9e-05, 'kernel': 'linear', 'rs': [0, 2, 3, 4, 8]} #2
#Params={'C': 7, 'epsilon': 0.01, 'gamma': 9e-05, 'kernel': 'linear', 'rs': [0, 2, 3, 5, 8, 9]} #1
#Params={'C': 1, 'epsilon': 0.01, 'gamma': 9e-05, 'kernel': 'linear', 'rs': [1, 4, 7]} #P/S, P/B
Params={'C': 1, 'epsilon': 0.01, 'gamma': 9e-05, 'kernel': 'linear'}
svr = SVR(kernel=Params['kernel'], C=Params['C'], gamma=Params['gamma'], epsilon=Params['epsilon'])
for stock in ['NSC', 'GL', 'PEP', 'BDX', 'IBM']:
    model_results_revised(datas[stock], svr, label=stock, scaling=True, start='1986-03')
# Out:
# NSC MODEL RESULTS
#  RMSE
#  	Test: 9.99931107514764
#  MAPE
#  	Test: 0.14668584902647236
#  MAE
#  	Test: 5.344600257429934
#  R2 Score Adj
#  	Test: 0.9424349050368097
# GL MODEL RESULTS
#  RMSE
#  	Test: 4.8072164878314325
#  MAPE
#  	Test: 0.1367508098378357
#  MAE
#  	Test: 2.839830398162532
#  R2 Score Adj
#  	Test: 0.9503714637202434
# PEP MODEL RESULTS
#  RMSE
#  	Test: 4.857251357048089
#  MAPE
#  	Test: 0.11519255495753895
#  MAE
#  	Test: 2.7647451654558535
#  R2 Score Adj
#  	Test: 0.9733744320413383
# BDX MODEL RESULTS
#  RMSE
#  	Test: 6.777463445139393
#  MAPE
#  	Test: 0.10403577499881077
#  MAE
#  	Test: 4.0495320554182745
#  R2 Score Adj
#  	Test: 0.9871645054279665
# IBM MODEL RESULTS
#  RMSE
#  	Test: 10.75480017699233
#  MAPE
#  	Test: 0.23512542781749102
#  MAE
#  	Test: 7.58937806083481
#  R2 Score Adj
#  	Test: 0.9300160416616188

# %% [markdown]
# ## 3.3 Sequential split - No scaled prediction variable

# %%
from lib.fundamental_lib import holdout
svr = GridSearchCV(SVR(), n_jobs=-1, #error_score=1,
                   param_grid={"kernel": ['linear', 'poly', 'rbf', 'sigmoid'],
                               "C": [1, 3, 5, 7],
                               "gamma": [0.00009, 0.00008, 0.00007, 0.00006, 0.0001],
                                "epsilon": [0.0001, 0.0003, 0.0005, 0.0008, 0.01]
                              },
                   scoring="neg_root_mean_squared_error"
)
data = pd.read_csv(PATH+'IBM_Manual_dataset.csv', header=0, index_col=0, low_memory=False)
data.sort_index(ascending=True, inplace=True)
holdout(data, svr, scaling=False, manual=True)

# %%
from lib.fundamental_lib import model_results_seq
#Results log
#Params={'C': 7, 'epsilon': 0.0001, 'gamma': 9e-05, 'kernel': 'linear', 'rs': [0, 2, 3, 4, 8]} #2
#Params={'C': 7, 'epsilon': 0.01, 'gamma': 9e-05, 'kernel': 'linear', 'rs': [0, 2, 3, 5, 8, 9]} #1
#Params={'C': 1, 'epsilon': 0.01, 'gamma': 9e-05, 'kernel': 'linear', 'rs': [1, 4, 7]} #P/S, P/B
#Params={'C': 1, 'epsilon': 0.0003, 'gamma': 9e-05, 'kernel': 'linear'}
Params={'C': 5, 'epsilon': 0.0001, 'gamma': 9e-05, 'kernel': 'linear'}
svr = SVR(kernel=Params['kernel'], C=Params['C'], gamma=Params['gamma'], epsilon=Params['epsilon'])
for stock in ['NSC', 'GL', 'PEP', 'BDX', 'IBM']:
    data = pd.read_csv(PATH+'Windowed_{}_Manual_dataset.csv'.format(stock), header=0, index_col=0, low_memory=False)
    data.sort_index(ascending=True, inplace=True)
    model_results_seq(data, svr, label=stock, scaling=False, start='1986-03')
# Out:
# NSC MODEL RESULTS
#  RMSE
#  	Train: 4.278338710837881
#  	Test: 27.252766551708703
#  	Dataset: 13.016908011402846
#  MAPE
#  	Train: 0.13178124009327896
#  	Test: 0.18206314991949138
#  	Dataset: 0.1422717104886758
#  R2 Score Adj
#  	Train: 0.9213411611656026
#  	Test: 0.2045342929502244
#  	Dataset: 0.9225634273181844
# GL MODEL RESULTS
#  RMSE
#  	Train: 2.6929762758104387
#  	Test: 11.033364471920638
#  	Dataset: 5.580059661606695
#  MAPE
#  	Train: 0.1613219699487391
#  	Test: 0.11955150442420981
#  	Dataset: 0.15260726850836964
#  R2 Score Adj
#  	Train: 0.9041540439359301
#  	Test: -0.14103351569602052
#  	Dataset: 0.9457197113689685
# PEP MODEL RESULTS
#  RMSE
#  	Train: 3.4219124587323746
#  	Test: 6.768980750300938
#  	Dataset: 4.338879979981786
#  MAPE
#  	Train: 0.10910995602192468
#  	Test: 0.05035803597581257
#  	Dataset: 0.09685236119216029
#  R2 Score Adj
#  	Train: 0.9549159762144813
#  	Test: 0.7667451602310414
#  	Dataset: 0.9833635723699395
# BDX MODEL RESULTS
#  RMSE
#  	Train: 4.81155406873175
#  	Test: 32.29387754677532
#  	Dataset: 15.359143473283398
#  MAPE
#  	Train: 0.11394757403173272
#  	Test: 0.1557938301158279
#  	Dataset: 0.12267808789100437
#  R2 Score Adj
#  	Train: 0.9550702641150849
#  	Test: 0.14329263055456887
#  	Dataset: 0.9463047562049455
# IBM MODEL RESULTS
#  RMSE
#  	Train: 9.21536765244951
#  	Test: 13.799773525953158
#  	Dataset: 10.340988096318434
#  MAPE
#  	Train: 0.15282783246812026
#  	Test: 0.09125933158789254
#  	Dataset: 0.13998260566577064
#  R2 Score Adj
#  	Train: 0.9361666855464977
#  	Test: -2.7300604971731395
#  	Dataset: 0.9454254702739012

# %% [markdown]
# ## 3.4. Sequential split - Scaled prediction variable

# %%
from lib.fundamental_lib import holdout
svr = GridSearchCV(SVR(), n_jobs=-1, #error_score=1,
                   param_grid={"kernel": ['linear', 'poly', 'rbf', 'sigmoid'],
                               "C": [1, 3, 5, 7],
                               "gamma": [0.00009, 0.00008, 0.00007, 0.00006, 0.0001],
                                "epsilon": [0.0001, 0.0003, 0.0005, 0.0008, 0.01]
                              },
                   scoring="neg_root_mean_squared_error"
)
data = pd.read_csv(PATH+'IBM_Manual_dataset.csv', header=0, index_col=0, low_memory=False)
data.sort_index(ascending=True, inplace=True)
holdout(data, svr, scaling=True, manual=True)

# %%
from lib.fundamental_lib import model_results_seq
#Results log
#Params={'C': 7, 'epsilon': 0.0001, 'gamma': 9e-05, 'kernel': 'linear', 'rs': [0, 2, 3, 4, 8]} #2
#Params={'C': 7, 'epsilon': 0.01, 'gamma': 9e-05, 'kernel': 'linear', 'rs': [0, 2, 3, 5, 8, 9]} #1
#Params={'C': 1, 'epsilon': 0.01, 'gamma': 9e-05, 'kernel': 'linear', 'rs': [1, 4, 7]} #P/S, P/B
#Params={'C': 1, 'epsilon': 0.0003, 'gamma': 9e-05, 'kernel': 'linear'}
Params={'C': 5, 'epsilon': 0.0001, 'gamma': 9e-05, 'kernel': 'linear'}
svr = SVR(kernel=Params['kernel'], C=Params['C'], gamma=Params['gamma'], epsilon=Params['epsilon'])
for stock in ['NSC', 'GL', 'PEP', 'BDX', 'IBM']:
    data = pd.read_csv(PATH+'Windowed_{}_Manual_dataset.csv'.format(stock), header=0, index_col=0, low_memory=False)
    data.sort_index(ascending=True, inplace=True)
    model_results_seq(data, svr, label=stock, scaling=True, start='1986-03')
# Out:
# NSC MODEL RESULTS
#  RMSE
#  	Train: 4.341722263617447
#  	Test: 22.545571331588434
#  	Dataset: 10.998476531829564
#  MAPE
#  	Train: 0.11360363164352587
#  	Test: 0.14117444526292844
#  	Dataset: 0.11935581577994797
#  R2 Score Adj
#  	Train: 0.9189932367109662
#  	Test: 0.4555941789254404
#  	Dataset: 0.9447165017876967
# GL MODEL RESULTS
#  RMSE
#  	Train: 2.628950415816783
#  	Test: 11.184419781801138
#  	Dataset: 5.618506139037155
#  MAPE
#  	Train: 0.14285214182801684
#  	Test: 0.10798132035136271
#  	Dataset: 0.1355769344695782
#  R2 Score Adj
#  	Train: 0.9086573664146731
#  	Test: -0.17249065409676612
#  	Dataset: 0.9449691548101965
# PEP MODEL RESULTS
#  RMSE
#  	Train: 3.480413080683804
#  	Test: 6.610000691218104
#  	Dataset: 4.324542175078592
#  MAPE
#  	Train: 0.11400148853179802
#  	Test: 0.04440623527151809
#  	Dataset: 0.09948161554943748
#  R2 Score Adj
#  	Train: 0.9533612969651234
#  	Test: 0.7775731992200621
#  	Dataset: 0.9834733406716456
# BDX MODEL RESULTS
#  RMSE
#  	Train: 4.430783551021762
#  	Test: 18.05572981457685
#  	Dataset: 9.140696694057803
#  MAPE
#  	Train: 0.10228771028423955
#  	Test: 0.07939275385358839
#  	Dataset: 0.09751106469798858
#  R2 Score Adj
#  	Train: 0.9619000685516598
#  	Test: 0.7321928245066356
#  	Dataset: 0.9809821936455166
# IBM MODEL RESULTS
#  RMSE
#  	Train: 9.004104412800801
#  	Test: 13.165369624365947
#  	Dataset: 10.016034035222136
#  MAPE
#  	Train: 0.14647431913477008
#  	Test: 0.09060396813643684
#  	Dataset: 0.1348179149696502
#  R2 Score Adj
#  	Train: 0.9390599077294072
#  	Test: -2.394986649368549
#  	Dataset: 0.9488014679836557
